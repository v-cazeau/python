# %% [markdown]
# ## Intro to Python
# this notebook has some basic Python commands

# %%
name = "Pepe"
age = 30 
awesome = True

# %%
print(name)
# Out:
# Pepe

# %%
def bouncer(age):
    if (age>=21):
        return "You can drink" 
    if (age >= 18):
        return "You can dance"
    return "Get out!"

# %%
bouncer(16)
# Out:
# 'Get out!'

# %%
bouncer(19)
# Out:
# 'You can dance'

# %%
bouncer(82)
# Out:
# 'You can drink'

# %%
for i in range(0,10):
    print("Python is cool! 🌞")
# Out:
# Python is cool! 🌞
# Python is cool! 🌞
# Python is cool! 🌞
# Python is cool! 🌞
# Python is cool! 🌞
# Python is cool! 🌞
# Python is cool! 🌞
# Python is cool! 🌞
# Python is cool! 🌞
# Python is cool! 🌞

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data = pd.DataFrame(np.random.randn(100,4), columns=['A','B','C','D'])

# %%
data.head()
# Out:
#           A         B         C         D
# 0 -1.832521  0.073347  0.098635 -0.267243
# 1  0.231452  0.717388  0.234516  1.497904
# 2 -1.483281 -0.295049  0.036532 -0.510749
# 3 -1.048598  0.417905  0.097376  0.515250
# 4 -0.221569 -1.203639  1.519198 -0.214694

# %%
data.tail()
# Out:
#            A         B         C         D
# 95 -0.014808  0.981263  0.584273 -0.645540
# 96 -0.915862  0.642430  0.103072  0.478286
# 97  1.113162 -0.954923 -2.198968 -1.025988
# 98 -0.726455  1.017585  0.421789 -0.018248
# 99 -1.088921  1.876292 -0.180124 -0.417336

# %%
plt.scatter(data['A'], data ['D'])

# %%
sns.pairplot(data)
